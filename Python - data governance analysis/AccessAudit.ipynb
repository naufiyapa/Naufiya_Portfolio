# %%
import pandas as pd
# step 1: Load the needed files and merge info
# load tagged catalog (with data classification)
tagged_catalog = pd.read_csv('tagged_catalog.csv')

#load employee access info
employees = pd.read_csv('employees.csv')

#show columns as samples to verify
print("Tagged catalog columns:", tagged_catalog.columns.tolist())
print(tagged_catalog.head())

print("employees columns:",employees.columns.tolist())
print(employees.head())
# Out:
# Tagged catalog columns: ['dataset_name', 'Column_name', 'sample_name', 'data_classification']
#   dataset_name  Column_name            sample_name data_classification
# 0    customers  customer_id               CUST1000          identifier
# 1    customers         name           Allison Hill                 PII
# 2    customers        email  jillrhodes@miller.com                 PII
# 3    customers          dob             1960-05-08                 PII
# 4    customers      country              Macedonia             General
# employees columns: ['employee_id', 'name', 'role', 'dataset_name', 'access_level']
#   employee_id               name                role  dataset_name  \
# 0      EMP200  Michael Valentine       data_engineer     customers
# 1      EMP201    Susan Davis DDS       data_engineer     customers
# 2      EMP202      Alicia Parker       data_engineer  transactions
# 3      EMP203     Gloria Miranda  compliance_officer     customers
# 4      EMP204      Zachary Moore  compliance_officer     customers
#
#   access_level
# 0         read
# 1         read
# 2         read
# 3         read
# 4   read_write

# %%
#Step 2: Define sensitive data categories to check
#Senistive categories that need restricted access
sensitive_categories= ['PII','Financial']


#Step 3: Identify which datasets contain sensitive data
#find dataset that have any sensitive columns
sensitive_datasets = tagged_catalog[tagged_catalog['data_classification'].isin(sensitive_categories)]['dataset_name'].unique()
print('Sensitive datasets:',sensitive_datasets)


#Step 4: Define access rules (example)
#Example access rules byb role for sensitive datasets
#Roles allowes to access sentsitive data fully

allowed_roles = ['Manager','data_engineer','compliance_officer']

#Roles not allowed to access sensitive datasets (or limited)
restricted_roles = ['intern','analyst']



#Step 5: Audit employee access
#Function to flag risky access
def audit_access(row):
    dataset = row['dataset_name']
    role = row['role'].lower()
    access = row['access_level'].lower()

    if dataset in sensitive_datasets:
        if role in restricted_roles:
            return 'RISK - Unauthorized access to sensitive data'
        elif role in allowed_roles and access =='read':
            return 'Warning -Limited access to sensitive data'
        else:
            return 'OK'

    else:
        return 'OK'

#apply the audit function 

employees['access_audit']= employees.apply(audit_access, axis=1)

#view eisky entries only
risk_report = employees[employees['access_audit'] != 'OK']

print(risk_report)

#Step 6: Save the audit report
risk_report.to_csv('access_risk_report.csv', index=False)
print("Access risk report saved as access_risk_report.csv")
# Out:
# Sensitive datasets: ['customers' 'employees' 'reports' 'transactions']
#    employee_id                  name                role  dataset_name  \
# 0       EMP200     Michael Valentine       data_engineer     customers
# 1       EMP201       Susan Davis DDS       data_engineer     customers
# 2       EMP202         Alicia Parker       data_engineer  transactions
# 3       EMP203        Gloria Miranda  compliance_officer     customers
# 9       EMP209              Lori Orr              intern  transactions
# 10      EMP210           Amanda Diaz             analyst  transactions
# 11      EMP211          Tracy Bishop             analyst       reports
# 12      EMP212          Rachel Young  compliance_officer  transactions
# 15      EMP215       Jessica Hammond              intern       reports
# 16      EMP216        Kathryn Barnes  compliance_officer       reports
# 17      EMP217         Curtis Jacobs  compliance_officer  transactions
# 18      EMP218          Amy Castillo       data_engineer  transactions
# 19      EMP219        Timothy Dawson             analyst       reports
# 23      EMP223          Stacey Arias             analyst     customers
# 28      EMP228        Kaitlyn Guerra  compliance_officer     customers
# 29      EMP229         Julie Gilbert             analyst       reports
# 31      EMP231            Todd Lynch  compliance_officer       reports
# 32      EMP232         Ricardo Young              intern     customers
# 35      EMP235  Mr. Mark Andrews DDS             analyst  transactions
# 36      EMP236           Aaron Gomez  compliance_officer       reports
# 37      EMP237       Chelsea Barnett       data_engineer     customers
# 38      EMP238        Heather Ashley              intern     customers
# 41      EMP241         James Burgess              intern     customers
# 44      EMP244           Brandi Bell       data_engineer     customers
# 45      EMP245          Marvin Greer              intern  transactions
# 46      EMP246      Veronica Mendoza             analyst  transactions
# 48      EMP248         Amanda Harris             analyst     customers
# 50      EMP250           James Ochoa             analyst     customers
# 52      EMP252        Scott Williams              intern       reports
# 53      EMP253          Denise Lloyd              intern       reports
# 55      EMP255            Gina Lopez             analyst       reports
# 58      EMP258         Zachary White             analyst       reports
# 61      EMP261           Jeremy West  compliance_officer     customers
# 62      EMP262          Susan Mendez              intern       reports
# 64      EMP264      Michael Sullivan              intern       reports
# 66      EMP266        Samuel Gregory              intern       reports
# 67      EMP267         Cameron Young              intern  transactions
# 69      EMP269        Christian Cole       data_engineer       reports
# 71      EMP271         Jacob Edwards             analyst     customers
# 72      EMP272         Tyler Johnson       data_engineer     customers
# 73      EMP273       Joseph Mcintyre             analyst     customers
# 74      EMP274      Reginald Padilla              intern       reports
# 75      EMP275          Logan Benson              intern  transactions
# 76      EMP276  Mrs. Brandy Jones MD              intern  transactions
# 77      EMP277       Yolanda Cochran       data_engineer     customers
# 78      EMP278    Victoria Contreras             analyst  transactions
# 80      EMP280  Christopher Mckinney             analyst       reports
# 81      EMP281           Carrie Ward             analyst  transactions
# 82      EMP282        William Conner              intern       reports
# 83      EMP283           Johnny Ward              intern       reports
# 84      EMP284            Julie Bird  compliance_officer  transactions
# 85      EMP285         Stephen Jones              intern  transactions
# 87      EMP287         Jason Andrews  compliance_officer  transactions
# 91      EMP291            Betty Shaw       data_engineer     customers
# 92      EMP292         Sandra Holmes              intern       reports
# 94      EMP294          Travis Stone              intern  transactions
# 95      EMP295        Blake Gonzalez              intern     customers
# 96      EMP296          Denise Weber              intern  transactions
# 98      EMP298        Lauren Jackson             analyst  transactions
# 99      EMP299      Stephanie Morgan              intern  transactions
#
#    access_level                                  access_audit
# 0          read     Warning -Limited access to sensitive data
# 1          read     Warning -Limited access to sensitive data
# 2          read     Warning -Limited access to sensitive data
# 3          read     Warning -Limited access to sensitive data
# 9          read  RISK - Unauthorized access to sensitive data
# 10         read  RISK - Unauthorized access to sensitive data
# 11         read  RISK - Unauthorized access to sensitive data
# 12         read     Warning -Limited access to sensitive data
# 15   read_write  RISK - Unauthorized access to sensitive data
# 16         read     Warning -Limited access to sensitive data
# 17         read     Warning -Limited access to sensitive data
# 18         read     Warning -Limited access to sensitive data
# 19         read  RISK - Unauthorized access to sensitive data
# 23   read_write  RISK - Unauthorized access to sensitive data
# 28         read     Warning -Limited access to sensitive data
# 29         read  RISK - Unauthorized access to sensitive data
# 31         read     Warning -Limited access to sensitive data
# 32         read  RISK - Unauthorized access to sensitive data
# 35   read_write  RISK - Unauthorized access to sensitive data
# 36         read     Warning -Limited access to sensitive data
# 37         read     Warning -Limited access to sensitive data
# 38         read  RISK - Unauthorized access to sensitive data
# 41   read_write  RISK - Unauthorized access to sensitive data
# 44         read     Warning -Limited access to sensitive data
# 45   read_write  RISK - Unauthorized access to sensitive data
# 46   read_write  RISK - Unauthorized access to sensitive data
# 48   read_write  RISK - Unauthorized access to sensitive data
# 50   read_write  RISK - Unauthorized access to sensitive data
# 52         read  RISK - Unauthorized access to sensitive data
# 53         read  RISK - Unauthorized access to sensitive data
# 55         read  RISK - Unauthorized access to sensitive data
# 58   read_write  RISK - Unauthorized access to sensitive data
# 61         read     Warning -Limited access to sensitive data
# 62   read_write  RISK - Unauthorized access to sensitive data
# 64         read  RISK - Unauthorized access to sensitive data
# 66   read_write  RISK - Unauthorized access to sensitive data
# 67   read_write  RISK - Unauthorized access to sensitive data
# 69         read     Warning -Limited access to sensitive data
# 71   read_write  RISK - Unauthorized access to sensitive data
# 72         read     Warning -Limited access to sensitive data
# 73         read  RISK - Unauthorized access to sensitive data
# 74         read  RISK - Unauthorized access to sensitive data
# 75         read  RISK - Unauthorized access to sensitive data
# 76   read_write  RISK - Unauthorized access to sensitive data
# 77         read     Warning -Limited access to sensitive data
# 78         read  RISK - Unauthorized access to sensitive data
# 80         read  RISK - Unauthorized access to sensitive data
# 81         read  RISK - Unauthorized access to sensitive data
# 82   read_write  RISK - Unauthorized access to sensitive data
# 83   read_write  RISK - Unauthorized access to sensitive data
# 84         read     Warning -Limited access to sensitive data
# 85   read_write  RISK - Unauthorized access to sensitive data
# 87         read     Warning -Limited access to sensitive data
# 91         read     Warning -Limited access to sensitive data
# 92         read  RISK - Unauthorized access to sensitive data
# 94   read_write  RISK - Unauthorized access to sensitive data
# 95         read  RISK - Unauthorized access to sensitive data
# 96         read  RISK - Unauthorized access to sensitive data
# 98   read_write  RISK - Unauthorized access to sensitive data
# 99         read  RISK - Unauthorized access to sensitive data
# Access risk report saved as access_risk_report.csv

# %%
# Out:
# Sensitive datasets: ['customers' 'employees' 'reports' 'transactions']
